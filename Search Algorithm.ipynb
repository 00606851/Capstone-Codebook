# %%
import pandas as pd
from colorama import Fore, Style, init
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
from colorama import Fore, Style
from better_profanity import profanity

# %%
#Understanding the dataset
file_path = '/Users/louisvsbigmac/Documents/Office 365/xlsx/Creative Careers.xlsx' 
spreadsheet = pd.ExcelFile(file_path)
df = spreadsheet.parse('Sheet1')
num_jobs = df.shape[0]
jobs_per_discipline = df['Discipline'].value_counts()
print(f'Total number of jobs: {num_jobs}')
print('Number of jobs per discipline:')
print(jobs_per_discipline)
# Out:
# Total number of jobs: 464
# Number of jobs per discipline:
# Discipline
# Moving Image & Theatre           103
# Arts & Crafts                     76
# Data and R&D                      60
# Culture & Heritage                54
# Marketing                         49
# Fashion & Textiles                35
# Music & Audio                     35
# Games & 3D                        22
# Architecture & Interiors          15
# Journalism & Creative Writing     15
# Name: count, dtype: int64

# %%
#Further previewing the dataset
grouped = df.groupby(['Discipline', 'Process', 'Function'])['Job'].apply(list).reset_index()
for discipline, discipline_df in grouped.groupby('Discipline'):
    print(f"Discipline: {discipline}")
    for _, row in discipline_df.iterrows():
        process = row['Process']
        function = row['Function']
        jobs = row['Job']
        print(f"  Process: {process}")
        print(f"    Function: {function}")
        for job in jobs:
            print(f"      Job: {job}")
    print()
# Out:
# Discipline: Architecture & Interiors
#   Process: Creatives
#     Function: Architects
#       Job: Architect
#       Job: Interior architect
#       Job: Landscape architect
#       Job: Naval architect
#   Process: Creatives
#     Function: Artists/Photographers
#       Job: Modelling artist
#   Process: Creatives
#     Function: Builders
#       Job: Furniture maker
#       Job: Model maker
#   Process: Creatives
#     Function: Designers
#       Job: Furniture designer
#       Job: Interior designer
#       Job: Kitchen and bathroom designer
#   Process: Creatives
#     Function: Tailors
#       Job: Upholsterer
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: Architectural technician
#       Job: Build engineer
#       Job: Furniture restorer
#   Process: Researchers
#     Function: Technologists/Researchers
#       Job: Architectural technologist
#
# Discipline: Arts & Crafts
#   Process: Creatives
#     Function: Artists/Photographers
#       Job: Calligrapher
#       Job: Concept artist
#       Job: Drawer/sketcher
#       Job: Environmental artist
#       Job: Fine Artist
#       Job: Illustrator
#       Job: Layout artist
#       Job: Medical illustrator
#       Job: Multi-disciplinary artist
#       Job: Painter
#       Job: Previsualisation artist
#       Job: Roto artist
#       Job: Surface decorator
#   Process: Creatives
#     Function: Builders
#       Job: Baker
#       Job: Basket maker
#       Job: Bicycle builder
#       Job: Blacksmith
#       Job: Carpenter
#       Job: Ceramicist
#       Job: Chain maker
#       Job: Clock maker
#       Job: Diamond mounter
#       Job: Enameller
#       Job: Engraver
#       Job: Forge operator
#       Job: French polisher
#       Job: Furniture maker
#       Job: Glass decorator
#       Job: Glassblower
#       Job: Glassmaker
#       Job: Goldsmith
#       Job: Jeweller
#       Job: Origami craftsperson
#       Job: Paper craftsperson
#       Job: Picture framer
#       Job: Potterer
#       Job: Printmaker
#       Job: Sculptor
#       Job: Setter
#       Job: Stonemason
#       Job: Studio potter
#       Job: Thatcher
#       Job: Theatre carpenter
#       Job: Veneerer
#       Job: Watch maker
#       Job: Wax carver
#       Job: Woodturner
#   Process: Creatives
#     Function: Designers
#       Job: Graphic artist/designer
#       Job: Industrial designer
#       Job: Inventor
#       Job: Product designer
#       Job: System designer
#       Job: Typographer
#       Job: UX designer
#   Process: Creatives
#     Function: Tailors
#       Job: Taxidermist
#   Process: Directors
#     Function: Directors
#       Job: Casting director
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Catering manager
#       Job: Construction manager
#       Job: Design manager
#       Job: Junior product manager
#   Process: Editors
#     Function: Editors
#       Job: Art editor
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: Armourer
#       Job: Assay office technician
#       Job: Casting technician
#       Job: Design and development engineer
#       Job: Electrical engineer
#       Job: Electrician
#       Job: Machinist
#       Job: Print finisher
#       Job: Print room operator
#       Job: Tools engineer
#   Process: Reactors
#     Function: Archivers/Restorers/Conservers
#       Job: Arts administrator
#       Job: Fine art conserver
#   Process: Reactors
#     Function: Critics/Reviewers
#       Job: Art valuer
#   Process: Reactors
#     Function: Teachers/Therapists
#       Job: Art therapist
#       Job: Gallery educator
#
# Discipline: Culture & Heritage
#   Process: Directors
#     Function: Executives/Officers/Heads Of
#       Job: Chief knowledge officer
#       Job: Equalities officer
#       Job: Legal affairs executive
#       Job: Rights executive
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Career service manager
#       Job: Front-of-house manager
#       Job: HR manager
#       Job: Talent manager
#       Job: Theatre education manager
#       Job: Tour manager
#   Process: Directors
#     Function: Producers/Fundraisers
#       Job: Celebrity producer
#       Job: Fundraiser
#   Process: Facilitators
#     Function: Performers
#       Job: BSL interpreter
#       Job: Sales assistant
#   Process: Facilitators
#     Function: Publishers
#       Job: Audio publisher
#       Job: Electronic publisher
#       Job: Interactive publisher
#       Job: Multi-media publisher
#       Job: Publisher
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: Royalties assistant
#       Job: Translator
#   Process: Reactors
#     Function: Archivers/Restorers/Conservers
#       Job: Archivist
#       Job: Cataloguer
#       Job: Conservator
#       Job: Data librarian
#       Job: Factual reporter
#       Job: Film archivist
#       Job: Fine art conserver
#       Job: Government librarian
#       Job: Healthcare librarian
#       Job: Indexer
#       Job: Librarian
#       Job: Public librarian
#       Job: Subject librarian
#       Job: Taxonomist
#   Process: Reactors
#     Function: Critics/Reviewers
#       Job: Art valuer
#       Job: Broadcast journalist
#       Job: Film critic
#       Job: Pundit
#   Process: Reactors
#     Function: Scholars/Historians
#       Job: Cinematics/Photography historian
#       Job: Dance historian
#       Job: Historian
#       Job: Music historian
#       Job: Musical instrument historian
#       Job: Musicologist
#   Process: Reactors
#     Function: Teachers/Therapists
#       Job: Drama teacher
#       Job: Education specialist
#       Job: Gallery educator
#       Job: Lecturer
#       Job: Movement therapist
#       Job: Music teacher
#       Job: Pilates instructor
#       Job: Yoga teacher
#   Process: Researchers
#     Function: Technologists/Researchers
#       Job: Sourcer
#
# Discipline: Data and R&D
#   Process: Creatives
#     Function: Architects
#       Job: Knowledge architect
#   Process: Creatives
#     Function: Choreographers
#       Job: Ergonomist
#   Process: Creatives
#     Function: Designers
#       Job: Software designer/developer/engineer
#   Process: Creatives
#     Function: Programmers
#       Job: AI programmer
#       Job: Audio programmer
#       Job: Engine programmer
#       Job: Film programmer
#       Job: Full stack developer
#       Job: Gameplay programmer
#       Job: Generalist programmer
#       Job: Graphics programmer
#       Job: Network programmer
#       Job: Physics programmer
#       Job: VR programmer
#   Process: Directors
#     Function: Directors
#       Job: Growth director
#       Job: New business director
#   Process: Directors
#     Function: Executives/Officers/Heads Of
#       Job: Insight executive
#       Job: Marketing research executive
#       Job: New business executive
#       Job: Research officer
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Business development manager
#       Job: Change manager
#       Job: Chaser
#       Job: Cyber-security manager
#       Job: Data analytics manager
#       Job: Facilities manager
#       Job: Information governance manager
#       Job: Network manager
#       Job: Operations manager
#       Job: Project manager/coordinator
#       Job: Resource manager
#       Job: Sales account manager
#       Job: Web manager
#   Process: Directors
#     Function: Producers/Fundraisers
#       Job: Development producer
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: Data capture technician
#       Job: Data input/output technician
#       Job: Devops
#       Job: Technical support person
#   Process: Reactors
#     Function: Archivers/Restorers/Conservers
#       Job: Arts administrator
#       Job: Data librarian
#       Job: Music data administrator
#   Process: Researchers
#     Function: Analysts
#       Job: Data analyst
#       Job: Data insight professional
#       Job: Data scientist
#       Job: Econometrician
#       Job: Group financial analyst
#       Job: Information analyst
#       Job: Market research data analyst
#       Job: Research analyst
#       Job: Senior data analyst
#       Job: Statistician
#   Process: Researchers
#     Function: Technologists/Researchers
#       Job: Analytical textiles technologist
#       Job: Architectural technologist
#       Job: Human factors specialist
#       Job: Information assistant
#       Job: Market research interviewer
#       Job: Market researcher
#       Job: Media researcher
#       Job: Research scientist
#       Job: Sourcer
#
# Discipline: Fashion & Textiles
#   Process: Creatives
#     Function: Artists/Photographers
#       Job: Make-up artist
#       Job: Photographic stylist
#       Job: Tattooist
#   Process: Creatives
#     Function: Builders
#       Job: Diamond mounter
#       Job: Jeweller
#       Job: Watch maker
#   Process: Creatives
#     Function: Designers
#       Job: Costume designer
#       Job: Fashion/clothes designer
#       Job: Footwear designer
#       Job: Hair designer
#       Job: Jewellery designer
#       Job: Textile designer
#       Job: Wardrobe designer
#   Process: Creatives
#     Function: Tailors
#       Job: Costume maker
#       Job: Dressmaker
#       Job: Embroiderer
#       Job: Industrial knitter
#       Job: Industrial sewing machinist
#       Job: Knitter
#       Job: Knitting machinist
#       Job: Leather craftworker
#       Job: Needlecrafts person
#       Job: Shoe maker
#       Job: Tailor
#       Job: Upholsterer
#       Job: Weaver
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Textiles production manager
#   Process: Facilitators
#     Function: Performers
#       Job: Fashion model
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: Leather technician
#       Job: Pattern cutter
#       Job: Sample machinist
#       Job: Spinner
#       Job: Textile technical specialist
#       Job: Wardrobe assistant
#   Process: Researchers
#     Function: Technologists/Researchers
#       Job: Analytical textiles technologist
#
# Discipline: Games & 3D
#   Process: Creatives
#     Function: Artists/Photographers
#       Job: Look development artist
#       Job: Matchmove artist
#       Job: Texture artist
#   Process: Creatives
#     Function: Designers
#       Job: 3D designer/modelling artist
#       Job: Economy designer
#       Job: Game designer
#       Job: Gameplay designer
#       Job: Interactive and electronic designer
#       Job: Level designer
#   Process: Creatives
#     Function: Programmers
#       Job: Engine programmer
#       Job: Gameplay programmer
#       Job: Graphics programmer
#       Job: Network programmer
#       Job: Physics programmer
#       Job: VR programmer
#   Process: Directors
#     Function: Directors
#       Job: Creature technical director
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Computer graphics supervisor
#   Process: Directors
#     Function: Producers/Fundraisers
#       Job: E-sports producer
#       Job: Games producer
#   Process: Facilitators
#     Function: Performers
#       Job: E sports shoutcaster
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: CAD technician
#       Job: Optical engineer
#
# Discipline: Journalism & Creative Writing
#   Process: Directors
#     Function: Directors
#       Job: Export sales director
#       Job: Rights director
#   Process: Directors
#     Function: Executives/Officers/Heads Of
#       Job: Head of story
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Script supervisor
#   Process: Directors
#     Function: Producers/Fundraisers
#       Job: Question producer
#   Process: Editors
#     Function: Editors
#       Job: Broadcast editor
#       Job: Commissioning editor
#       Job: Edit/Editorial assistant
#       Job: Magazine editor
#   Process: Facilitators
#     Function: Performers
#       Job: TV presenter
#   Process: Facilitators
#     Function: Publishers
#       Job: Publisher
#   Process: Reactors
#     Function: Archivers/Restorers/Conservers
#       Job: Librarian
#       Job: Public librarian
#   Process: Reactors
#     Function: Critics/Reviewers
#       Job: Broadcast journalist
#       Job: Film critic
#
# Discipline: Marketing
#   Process: Creatives
#     Function: Artists/Photographers
#       Job: Artworker
#   Process: Creatives
#     Function: Designers
#       Job: Exhibition designer
#   Process: Directors
#     Function: Directors
#       Job: Advertising account director
#       Job: Art director
#       Job: Communication director
#       Job: Festival director
#       Job: Growth director
#       Job: Media account director
#       Job: New business director
#       Job: Publicity director
#   Process: Directors
#     Function: Executives/Officers/Heads Of
#       Job: Advertising account executive
#       Job: Biddable executive
#       Job: Chief marketing officer
#       Job: Communications officer
#       Job: Digital marketing executive
#       Job: Head of marketing
#       Job: Marketing executive
#       Job: Marketing research executive
#       Job: Pay-per-click executive
#       Job: PR executive
#       Job: Press executive
#       Job: Sales executive
#       Job: Search engine optimisation executive
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Account handler/manager
#       Job: Community manager
#       Job: Conference and exhibition manager
#       Job: Digital marketing manager
#       Job: Event manager
#       Job: Marketing manager
#       Job: Outreach manager
#       Job: Publicity manager
#       Job: Social media manager
#       Job: Special sales coordinator
#   Process: Directors
#     Function: Producers/Fundraisers
#       Job: Agency producer
#       Job: Deliverables producer
#       Job: Digital producer
#   Process: Directors
#     Function: Strategists/Planners
#       Job: Advertising account planner
#       Job: Communications planner
#       Job: Junior account planner
#       Job: Media strategist
#       Job: Senior account planner
#       Job: Strategic planner
#   Process: Editors
#     Function: Editors
#       Job: Copy editor
#       Job: Web editor
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: Event technician
#       Job: Exhibition builder
#       Job: Production assistant
#       Job: Window dresser/ Display assistant
#       Job: Reprographic assistant
#
# Discipline: Moving Image & Theatre
#   Process: Creatives
#     Function: Artists/Photographers
#       Job: Character artist
#       Job: Lighting artist
#       Job: Make-up artist
#       Job: Modelling artist
#       Job: Photographer
#       Job: Photographic stylist
#       Job: Roto artist
#       Job: Set decorator
#   Process: Creatives
#     Function: Builders
#       Job: Model maker
#       Job: Theatre carpenter
#   Process: Creatives
#     Function: Choreographers
#       Job: Animator
#       Job: Choreographer
#       Job: Choreologist
#       Job: Cinematographer
#       Job: Technical animator
#   Process: Creatives
#     Function: Designers
#       Job: Background designer
#       Job: Costume designer
#       Job: Hair designer
#       Job: Puppet designer
#       Job: Stage designer
#       Job: Theatre designer
#       Job: Wardrobe designer
#   Process: Creatives
#     Function: Programmers
#       Job: Film programmer
#   Process: Creatives
#     Function: Tailors
#       Job: Costume maker
#   Process: Directors
#     Function: Directors
#       Job: Animation technical director
#       Job: Archive producer
#       Job: Director of photography
#       Job: Fight director
#       Job: Film director
#       Job: Flyperson
#       Job: Layout technical director
#       Job: Pipeline technical director
#       Job: Rigging technical director
#       Job: Visual effects technical director
#   Process: Directors
#     Function: Executives/Officers/Heads Of
#       Job: Access officer
#       Job: Distribution executive
#       Job: Head of story
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Box-office manager
#       Job: Compositing supervisor
#       Job: Dance captain
#       Job: Film marketing manager
#       Job: Film production manager/coordinator
#       Job: Locations manager
#       Job: Post-production supervisor
#       Job: Puppet master
#       Job: Script supervisor
#       Job: Stage manager
#       Job: Theatre education manager
#       Job: VFX supervisor
#   Process: Directors
#     Function: Producers/Fundraisers
#       Job: Edit producer
#       Job: Film producer
#       Job: Line producer
#       Job: Media producer
#       Job: Theatre fundraiser
#       Job: Theatre producer
#   Process: Editors
#     Function: Editors
#       Job: Account production editor
#       Job: Colourist
#       Job: Supervising editor
#       Job: Video editor
#       Job: Visual and audio effects person
#   Process: Facilitators
#     Function: Performers
#       Job: Actor musician
#       Job: Actor/actress
#       Job: Cabaret artist
#       Job: Circus performer
#       Job: Dancer
#       Job: Entertainer
#       Job: Musical theatre performer
#       Job: TV presenter
#       Job: Voice-over artist
#   Process: Facilitators
#     Function: Publishers
#       Job: Film publicist
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: Audio visual technician
#       Job: Backstage crew member
#       Job: Compositor
#       Job: Digital image technician
#       Job: Dresser
#       Job: Drone pilot
#       Job: Film and sound recorder
#       Job: Film camera operator
#       Job: Film production runner
#       Job: Film sound technician
#       Job: Floor runner
#       Job: Gaffer
#       Job: Grip
#       Job: Lighting technician
#       Job: Moving image technician
#       Job: Paint prep artist
#       Job: Photographic technician
#       Job: Post-production runner
#       Job: Props technician
#       Job: Rigger
#       Job: Scenic Automator
#       Job: Stage hand/technician
#       Job: Subtitler
#       Job: Sync assistant
#       Job: Theatre electrician
#       Job: Video assistant operator
#       Job: Wardrobe assistant
#   Process: Reactors
#     Function: Archivers/Restorers/Conservers
#       Job: Film archivist
#   Process: Reactors
#     Function: Critics/Reviewers
#       Job: Film critic
#   Process: Reactors
#     Function: Scholars/Historians
#       Job: Cinematics/Photography historian
#       Job: Dance historian
#   Process: Reactors
#     Function: Teachers/Therapists
#       Job: Dance scientist
#       Job: Drama teacher
#
# Discipline: Music & Audio
#   Process: Creatives
#     Function: Artists/Photographers
#       Job: Musician
#   Process: Creatives
#     Function: Choreographers
#       Job: Choreographer
#       Job: Choreologist
#   Process: Creatives
#     Function: Designers
#       Job: Sound designer
#   Process: Creatives
#     Function: Programmers
#       Job: Audio programmer
#   Process: Directors
#     Function: Directors
#       Job: Musical director
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: A&R manager
#       Job: Dance captain
#       Job: Music promotions manager
#       Job: Studio manager
#   Process: Directors
#     Function: Producers/Fundraisers
#       Job: Audio producer
#       Job: Music producer
#       Job: Radio producer
#   Process: Facilitators
#     Function: Performers
#       Job: Actor musician
#       Job: Dancer
#       Job: DJ
#       Job: Musical theatre performer
#       Job: Orchestra musician
#       Job: Radio presenter
#       Job: Session musician
#   Process: Facilitators
#     Function: Publishers
#       Job: Audio publisher
#       Job: Radio broadcast assistant
#   Process: Facilitators
#     Function: Technicians/Engineers/Recorders
#       Job: Sound mixer
#       Job: Sound engineer/technician
#       Job: Radio broadcast assistant
#       Job: Sound recorder
#       Job: Studio maintenance engineer
#   Process: Reactors
#     Function: Archivers/Restorers/Conservers
#       Job: Music data administrator
#   Process: Reactors
#     Function: Scholars/Historians
#       Job: Dance historian
#       Job: Music historian
#       Job: Musical instrument historian
#       Job: Musicologist
#   Process: Reactors
#     Function: Teachers/Therapists
#       Job: Dance scientist
#       Job: Music teacher
#       Job: Music therapist

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import pandas as pd
from colorama import Fore, Style
from better_profanity import profanity
# Custom list of offensive words
custom_offensive_words = [
    'racist', 'idiot', 'stupid', 'dumb', 'moron', 'jerk', 'asshole', 'bastard',
    'dickhead', 'shithead', 'retard', 'loser', 'freak', 'creep', 'scumbag',
    # More offensive words are needed!
]
# Load the custom list into the profanity filter
profanity.load_censor_words(custom_offensive_words)


# Extended keyword-to-job mapping for holistic recommendations
keyword_to_job = {
    'wood': ['Carpenter', 'Woodworker', 'Furniture maker'],
    'data': ['Data analyst', 'Data scientist', 'Statistician'],
    'architecture': ['Architect', 'Architectural technologist'],
    'science': ['Scientist', 'Researcher', 'Data scientist', 'Biologist', 'Chemist'],
    'engineering': ['Engineer', 'Mechanical engineer', 'Electrical engineer', 'Civil engineer'],
    # More keyword-to-job mappings are needed!
}


def fuzzy_match(prompt, choices, score_threshold=80):
    matches = process.extract(prompt, choices, limit=10, scorer=fuzz.partial_ratio)
    return [match for match in matches if match[1] >= score_threshold]

def recommend_jobs(prompt, df):
    prompt = prompt.lower()
    
    # Check if the prompt contains offensive words
    if profanity.contains_profanity(prompt):
        return "The prompt contains offensive language. Please try again with appropriate language."
    
    # Check if the prompt matches any keywords in the mapping
    if prompt in keyword_to_job:
        related_jobs = keyword_to_job[prompt]
        matching_jobs = df[df['Job'].str.lower().isin([job.lower() for job in related_jobs])]
        if not matching_jobs.empty:
            return matching_jobs[['Discipline', 'Process', 'Function', 'Job']]
    
    # Extract unique values for each column to compare against
    disciplines = df['Discipline'].str.lower().unique()
    functions = df['Function'].str.lower().unique()
    processes = df['Process'].str.lower().unique()
    jobs = df['Job'].str.lower().unique()
    
    # Perform fuzzy matching on each column
    matching_disciplines = fuzzy_match(prompt, disciplines)
    matching_functions = fuzzy_match(prompt, functions)
    matching_processes = fuzzy_match(prompt, processes)
    matching_jobs = fuzzy_match(prompt, jobs)
    
    # Collect all matches found
    matches = set()
    for match in matching_disciplines:
        matches.update(df[df['Discipline'].str.lower() == match[0]].index)
    for match in matching_functions:
        matches.update(df[df['Function'].str.lower() == match[0]].index)
    for match in matching_processes:
        matches.update(df[df['Process'].str.lower() == match[0]].index)
    for match in matching_jobs:
        matches.update(df[df['Job'].str.lower() == match[0]].index)
    
    # If no matches are found, return a message indicating no matches
    if not matches:
        return f"No jobs found matching the prompt: {prompt}"
    
    # Convert the set of matches to a list before using it as an indexer
    matching_jobs = df.loc[list(matches), ['Discipline', 'Process', 'Function', 'Job']]
    return matching_jobs

# Simple command-line interface for user interaction
def main():
    print(Fore.CYAN + "Welcome to the Job Recommendation App!" + Style.RESET_ALL)
    print("Enter a prompt to find appropriate jobs (e.g., 'Manager', 'Technologist'): ")
    
    while True:
        prompt = input(Fore.YELLOW + "Enter your prompt (or 'exit' to quit): " + Style.RESET_ALL)
        if prompt.lower() == 'exit':
            print(Fore.CYAN + "Thank you for using the Job Recommendation App. Goodbye!" + Style.RESET_ALL)
            break
        
        recommendations = recommend_jobs(prompt, df)
        
        print(Fore.GREEN + "\nRecommended Jobs:" + Style.RESET_ALL)
        if isinstance(recommendations, str):
            print(Fore.RED + recommendations + Style.RESET_ALL)
        else:
            for _, row in recommendations.iterrows():
                print(Fore.BLUE + f"Discipline: {row['Discipline']}" + Style.RESET_ALL)
                print(Fore.MAGENTA + f"  Process: {row['Process']}" + Style.RESET_ALL)
                print(Fore.YELLOW + f"    Function: {row['Function']}" + Style.RESET_ALL)
                print(Fore.CYAN + f"      Job: {row['Job']}" + Style.RESET_ALL)
                print(Fore.WHITE + "-"*40 + Style.RESET_ALL)  # Separator for better readability

if __name__ == "__main__":
    # Load the dataset
   
    file_path = '/Users/louisvsbigmac/Documents/Office 365/xlsx/Creative Careers.xlsx' 
    df = pd.read_excel(file_path, sheet_name='Sheet1')
    main()
# Out:
# Welcome to the Job Recommendation App!
# Enter a prompt to find appropriate jobs (e.g., 'Manager', 'Technologist'):
# Enter your prompt (or 'exit' to quit): car
#
# Recommended Jobs:
# Discipline: Arts & Crafts
#   Process: Creatives
#     Function: Builders
#       Job: Wax carver
# ----------------------------------------
# Discipline: Culture & Heritage
#   Process: Directors
#     Function: Managers/Supervisors/Coordinators
#       Job: Career service manager
# ----------------------------------------
# Discipline: Culture & Heritage
#   Process: Reactors
#     Function: Archivers/Restorers/Conservers
#       Job: Healthcare librarian
# ----------------------------------------
# Discipline: Arts & Crafts
#   Process: Creatives
#     Function: Builders
#       Job: Theatre carpenter
# ----------------------------------------
# Discipline: Moving Image & Theatre
#   Process: Creatives
#     Function: Builders
#       Job: Theatre carpenter
# ----------------------------------------
# Discipline: Arts & Crafts
#   Process: Creatives
#     Function: Builders
#       Job: Carpenter
# ----------------------------------------
# Enter your prompt (or 'exit' to quit): exit
# Thank you for using the Job Recommendation App. Goodbye!
